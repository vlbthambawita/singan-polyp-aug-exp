# %%
from singan_polyp_aug import generate_data, prepare_requirements

# %%
import pandas as pd

# %%
help(prepare_requirements.prepare_checkpoints)
# Out:
# Help on function prepare_checkpoints in module singan_polyp_aug.prepare_requirements:
#
# prepare_checkpoints(path_to_checkpoints: str, link_keys=['link1', 'link2', 'link3', 'link4'], real_data=True, *args, **kwargs) -> str
#     The main function preparing checkpoints for pre-trained SinGANs of Polyp images.
#
#     Parameters
#     -----------
#     path_to_checkpoints: str
#         A directory path to download checkpoints.
#     link_keys: list
#         A list of link keys: link1, link2, link3, link4. One or multiple link keys can be put in this list.
#     real_data: bool
#         If True, the real images and masks used to train SinGANs will be downloaded to the checkpoint directory.
#
#     Return
#     ------
#     checkpoint_paths_list, real_image_mask_pair_list
#         A sorted list of paths to downloaded checkpoints.
#         A sorted (image_path, mask_path) tuple list.

# %%
help(generate_data)
# Out:
# Help on module singan_polyp_aug.generate_data in singan_polyp_aug:
#
# NAME
#     singan_polyp_aug.generate_data
#
# FUNCTIONS
#     generate_from_multiple_checkpoints(out_dir: str, checkpoint_paths: list, *args, **kwargs) -> None
#         A function to generate synthetic polyp and correspondign mask from a given list of checkpoint paths.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         checkpoint_paths: list
#             A path list to downloaded checkpoints. To get paths, you have to run prepare_requirements.prepare_checkpoints() function.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
#     generate_from_single_checkpoint(out_dir: str, checkpoint_path: str, num_samples: int = 1, gen_start_scale: int = 5, mask_post_processing: bool = True) -> None
#         A function to generate synthetic polyp and correspondign mask from a given checkpoint path.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         checkpoint_path: str
#             A path to a downloaded checkpoint. To get paths, you have to run prepare_requirements.prepare_checkpoints() function.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
#     generate_simple(out_dir: str, chk_dir: str, *args, **kwargs) -> None
#         A function to generate synthetic polyp and correspondign mask from all downloaded checkpoint paths.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         chk_dir: str
#             The path to checkpoint directory. If the directory does not have downloaded checkpoints, this function will download them.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
# DATA
#     __warningregistry__ = {'version': 25}
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#
# FILE
#     /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug/generate_data.py

# %%
output_dir = "/work/vajira/DATA/sinGAN_polyps/singan_out"

# %%
paths, reals = prepare_requirements.prepare_checkpoints("/work/vajira/DATA/sinGAN_polyps/singan_test_2", link_keys=["link1", "link2", "link3", "link4"], real_data=True)
# Out:
# /work/vajira/DL/singan-polyp-aug-exp
# /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug
# /work/vajira/DL/singan-polyp-aug-exp
# /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug
# https://www.dropbox.com/s/19xq87x4xanuy4t/TrainedModels_1_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_1_clean is already exists.
# https://www.dropbox.com/s/0i7io4tkpoccmq4/TrainedModels_2_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_2_clean is already exists.
# https://www.dropbox.com/s/hsdpkifid9prtst/TrainedModels_3_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_3_clean is already exists.
# https://www.dropbox.com/s/hzu470zcmy5ygf1/TrainedModels_4_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean is already exists.
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/real_images is already exists.
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/real_masks is already exists.

# %%
len(reals)
# Out:
# 1000

# %%
len(paths)
# Out:
# 1000

# %%
#paths

# %%
#generate_data.generate_from_single_checkpoint(output_dir, paths[101], gen_start_scale=0, num_samples=5)

# %%
generate_data.generate_simple(output_dir, "/work/vajira/DATA/sinGAN_polyps/singan_test_2")
# Out:
# /work/vajira/DL/singan-polyp-aug-exp
# /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug
# /work/vajira/DL/singan-polyp-aug-exp
# /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug
# https://www.dropbox.com/s/19xq87x4xanuy4t/TrainedModels_1_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_1_clean is already exists.
# https://www.dropbox.com/s/0i7io4tkpoccmq4/TrainedModels_2_clean.zip?dl=1
# The directory:/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_2_cl

#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/913',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/914',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/915',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/916',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/917',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/918',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/919',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/920',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/921',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/922',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/923',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/924',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/925',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/926',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/927',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/928',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/929',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/930',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/931',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/932',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/933',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/934',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/935',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/936',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/937',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/938',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/939',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/940',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/941',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/942',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/943',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/944',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/945',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/946',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/947',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/948',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/949',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/950',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/951',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/952',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/953',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/954',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/955',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/956',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/957',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/958',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/959',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/960',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/961',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/962',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/963',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/964',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/965',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/966',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/967',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/968',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/969',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/970',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/971',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/972',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/973',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/974',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/975',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/976',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/977',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/978',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/979',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/980',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/981',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/982',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/983',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/984',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/985',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/986',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/987',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/988',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/989',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/990',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/991',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/992',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/993',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/994',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/995',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/996',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/997',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/998',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/999',
#  '/work/vajira/DATA/sinGAN_polyps/singan_test_2/TrainedModels_4_clean/1000']

# %%
help(generate_data)
# Out:
# Help on module singan_polyp_aug.generate_data in singan_polyp_aug:
#
# NAME
#     singan_polyp_aug.generate_data
#
# FUNCTIONS
#     generate_from_multiple_checkpoints(out_dir: str, checkpoint_paths: list, *args, **kwargs) -> None
#         A function to generate synthetic polyp and correspondign mask from a given list of checkpoint paths.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         checkpoint_paths: list
#             A path list to downloaded checkpoints. To get paths, you have to run prepare_requirements.prepare_checkpoints() function.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
#     generate_from_single_checkpoint(out_dir: str, checkpoint_path: str, num_samples: int = 1, gen_start_scale: int = 5, mask_post_processing: bool = True) -> None
#         A function to generate synthetic polyp and correspondign mask from a given checkpoint path.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         checkpoint_path: str
#             A path to a downloaded checkpoint. To get paths, you have to run prepare_requirements.prepare_checkpoints() function.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
#     generate_simple(out_dir: str, chk_dir: str, *args, **kwargs) -> None
#         A function to generate synthetic polyp and correspondign mask from all downloaded checkpoint paths.
#
#         Parameters
#         ----------
#         out_dir: str
#             A path to save output data.
#         chk_dir: str
#             The path to checkpoint directory. If the directory does not have downloaded checkpoints, this function will download them.
#         num_samples: int
#             Number of random samples to generate from the given checkpoint. Default=1.
#         gen_start_scale: int
#             Predefined scales used in SinGAN training. You can use values between 0-9. Value 0 generates more random samples and value 9 generate sampels which are
#             very close to the training image.
#         mask_post_processing: bool
#             Whether the generated mask should be post processed or not. If True, generates mask is cleaned to have only 0 and 255.
#
#         Returns
#         ------
#         None
#             This function does not have a return.
#
# DATA
#     __warningregistry__ = {'version': 25}
#     print_function = _Feature((2, 6, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0)...
#
# FILE
#     /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug/generate_data.py

# %%
generate_data.generate_simple("/work/vajira/DATA/sinGAN_polyps/singan_test_2", "/work/vajira/DATA/sinGAN_polyps/singan_test_2")
# Out:
# /work/vajira/DL/singan-polyp-aug-exp
# /work/vajira/anaconda3/envs/pytorch-new/lib/python3.8/site-packages/singan_polyp_aug
# https://www.dropbox.com/s/19xq87x4xanuy4t/TrainedModels_1_clean.zip?dl=1
# TrainedModels_1_clean.zip: 100%|██████████| 1.26G/1.26G [01:14<00:00, 18.2MB/s]
# Extracting TRUE...!
# === Extracting files ===
# 100%|██████████| 2502/2502 [00:10<00:00, 234.41it/s]
# https://www.dropbox.com/s/0i7io4tkpoccmq4/TrainedModels_2_clean.zip?dl=1
# TrainedModels_2_clean.zip: 100%|██████████| 1.24G/1.24G [00:57<00:00, 23.3MB/s]
# Extracting TRUE...!
# === Extracting files ===
# 100%|██████████| 2502/2502 [00:10<00:00, 237.91it/s]
#   0%|          | 0/500 [00:00<?, ?it/s]
# 0
# 100%|██████████| 500/500 [00:58<00:00,  8.56it/s]
